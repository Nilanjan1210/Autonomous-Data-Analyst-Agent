# %%
import os
from dotenv import load_dotenv
load_dotenv()

import pandas as pd
import numpy as np

import tempfile
import csv

import seaborn
import matplotlib.pyplot as plt

from langchain_groq import ChatGroq
# Out:
# True

# %%
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
if not GROQ_API_KEY:
    api_key = input("Enter your GROQ API key: ").strip()
else:
    print("✅ GROQ_API_KEY is set successfully.")
# Out:
# ✅ GROQ_API_KEY is set successfully.

# %%
def get_llm(model: str = "openai/gpt-oss-120b", temperature: float = 1.0) -> ChatGroq:
    """
    Returns a ChatGroq LLM instance with the given model and temperature.
    """
    return ChatGroq(
        model=model,
        temperature=temperature
    )

# %%
def preprocess_and_save(file_path):
     try:
          global df
          if file_path.endswith(".csv"):
               df = pd.read_csv(file_path, encoding='utf-8', na_values=['NA', 'N/A', 'missing'])
          elif file_path.endswith(".xlxs"):
               df = pd.read_excel(file_path, na_values=['NA', 'N/A', 'missing'])
          else:
               return None, "Unsupported file format."
          
           # Clean text columns
          for col in df.select_dtypes(include=['object']):
               df[col] = df[col].astype(str).replace({r'"': '""'}, regex=True)
          
          # Convert dates and numerics
          for col in df.columns:
               if 'date' in col.lower():
                    df[col] = pd.to_datetime(df[col], errors='coerce')
               elif df[col].dtype == 'object':
                    try:
                         df[col] = pd.to_numeric(df[col])
                    except:
                         pass
          return df, None
     except Exception as e:
          return None, str(e)

# %%
prompt = f"""
You are an expert Python data analyst assistant.

You are provided with a pandas DataFrame called `df`. 
Your job is to **generate Python code** that directly answers the user's data-related question using pandas, numpy, matplotli, seaborn built-in Python methods.

### Guidelines:
- Only return **pure Python code** (no text, no explanations).
- Always assign the **final answer** to a variable named `result`.
- **Do not modify `df` directly** — if you need to transform or filter data, create a copy (e.g., `df_copy = df.copy()`).
- The code should be **ready to execute** in a Python environment.
- If a visualization or statistical summary is needed, generate it in code form (e.g., using `matplotlib`, `seaborn`, or `pandas` plotting functions).
- Never include print statements or comments.
- Output must be inside a **single Python code block**.
"""

# %%
from langchain.messages  import HumanMessage, AIMessage, SystemMessage
def QA_on_data(file_path):
    model = get_llm()
    if not GROQ_API_KEY:
        print("❌ Please provide your Groq API key.")
    else:
        try:
            df, err = preprocess_and_save(file_path)
            df_col_name = df.columns
            if err:
                print(f"❌ Error: {err}")
            else:
                print("✅ File successfully processed.")
                print("\n📊 Preview of first 5 rows:")
                print(df.head())
            chat_history = [SystemMessage(prompt+f"The available columns in `df` are:{df_col_name}")]
            while True:
                query = input("Give your prompt?")
                if query.strip().lower() == exit:
                    break
                print(query)
                chat_history.append(HumanMessage(query))
                reponse = model.invoke(chat_history)
                chat_history.append(AIMessage(reponse.content))
                code_generated = reponse.content.strip("```python").strip("```")
                print("\n🤖 Generated Code:\n")
                print(code_generated)



                local_vars = {"df": df}
                exec(code_generated, {}, local_vars)
                
                result = local_vars.get("result", "⚠️ No result generated.")
                print("\n📈 Final Result:\n")
                if isinstance(result, pd.DataFrame):
                    print(result.to_string(index=False))
                else:
                    print(result)
        except Exception as e:
            print(f"❌ Exception occurred: {e}")

# %%
DATA_FILE_PATH = r"D:\Agentic_AI\autonomous-data-analyst\Data_Analyst\data\datasets\insurance.csv"

# %%
QA_on_data(DATA_FILE_PATH)
# Out:
# ✅ File successfully processed.
#
# 📊 Preview of first 5 rows:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# can you summary of my df
#
# 🤖 Generated Code:
#
#
# result = df.describe(include='all')
#
#
# 📈 Final Result:
#
#         age  sex         bmi    children smoker    region      charges
# 1338.000000 1338 1338.000000 1338.000000   1338      1338  1338.000000
#         NaN    2         NaN         NaN      2         4          NaN
#         NaN male         NaN         NaN     no southeast          NaN
#         NaN  676         NaN         NaN   1064       364          NaN
#   39.207025  NaN   30.663397    1.094918    NaN       NaN 13270.422265
#   14.049960  NaN    6.098187    1.205493    NaN       NaN 12110.011237
#   18.000000  NaN   15.960000    0.000000    NaN       NaN  1121.873900
#   27.000000  NaN   26.296250    0.000000    NaN       NaN  4740.287150
#   39.000000  NaN   30.400000    1.000000    NaN       NaN  9382.033000
#   51.000000  NaN   34.693750    2.000000    NaN       NaN 16639.912515
#   64.000000  NaN   53.130000    5.000000    NaN       NaN 63770.428010
# how many row have missing value
#
# 🤖 Generated Code:
#
#
# result = df.isnull().any(axis=1).sum()
#
#
# 📈 Final Result:
#
# 0
# check the outliers
#
# 🤖 Generated Code:
#
#
# import numpy as np
#
# numeric_cols = ['age', 'bmi', 'children', 'charges']
# df_copy = df.copy()
#
# outlier_masks = []
# for col in numeric_cols:
#     Q1 = df_copy[col].quantile(0.25)
#     Q3 = df_copy[col].quantile(0.75)
#     IQR = Q3 - Q1
#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR
#     outlier_mask = (df_copy[col] < lower_bound) | (df_copy[col] > upper_bound)
#     outlier_masks.append(outlier_mask)
#
# combined_outlier_mask = np.logical_or.reduce(outlier_masks)
# result = df_copy[combined_outlier_mask]
#
#
# 📈 Final Result:
#
#  age    sex    bmi  children smoker    region     charges
#   27   male 42.130         0    yes southeast 39611.75770
#   30   male 35.300         0    yes southwest 36837.46700
#   34 female 31.920         1    yes northeast 37701.87680
#   31   male 36.300         2    yes southwest 38711.00000
#   22   male 35.600         0    yes southwest 35585.57600
#   28   male 36.400         1    yes southwest 51194.55914
#   35   male 36.670         1    yes northeast 39774.27630
#   60   male 39.900         0    yes southwest 48173.36100
#   36   male 35.200         1    yes southeast 38709.17600
#   36   male 34.430         0    yes southeast 37742.57570
#   58   male 36.955         2    yes northwest 47496.49445
#   22   male 37.620         1    yes southeast 37165.16380
#   37 female 34.800         2    yes southwest 39836.51900
#   57 female 31.160         0    yes northwest 43578.93940
#   64 female 31.300         2    yes southwest 47291.05500
#   63   male 35.090         0    yes southeast 47055.53210
#   58   male 49.060         0     no southeast 11381.32540
#   44   male 31.350         1    yes northeast 39556.49450
#   46   male 30.495         3    yes northwest 40720.55105
#   30   male 35.530         0    yes southeast 36950.25670
#   18 female 36.850         0    yes southeast 36149.48350
#   63 female 37.700         0    yes southwest 48824.45000
#   36   male 41.895         3    yes northeast 43753.33705
#   27 female 36.080         0    yes southeast 37133.89820
#   19   male 34.800         0    yes southwest 34779.61500
#   23 female 36.670         2    yes northeast 38511.62830
#   55 female 26.800         1     no southwest 35160.13457
#   63 female 32.200         2    yes southwest 47305.30500
#   54   male 34.210         2    yes southeast 44260.74990
#   50   male 31.825         0    yes northeast 41097.16175
#   56   male 33.630         0    yes northwest 43921.18370
#   19   male 36.955         0    yes northwest 36219.40545
#   46   male 42.350         3    yes southeast 46151.12450
#   50   male 34.200         2    yes southwest 42856.83800
#   54   male 40.565         3    yes northeast 48549.17835
#   46 female 48.070         2     no northeast  9432.92530
#   59 female 36.765         1    yes northeast 47896.79135
#   25   male 45.540         2    yes southeast 42112.23560
#   31   male 34.390         3    yes northwest 38746.35510
#   43   male 35.970         3    yes southeast 42124.51530
#   27 female 31.400         0    yes southwest 34838.87300
#   34   male 30.800         0    yes southwest 35491.64000
#   45   male 36.480         2    yes northwest 42760.50220
#   64 female 33.800         1    yes southwest 47928.03000
#   61 female 36.385         1    yes northeast 48517.56315
#   50   male 32.300         1    yes northeast 41919.09700
#   26   male 32.900         2    yes southwest 36085.21900
#   24   male 40.150         0    yes southeast 38126.24650
#   55   male 30.685         0    yes northeast 42303.69215
#   47   male 47.520         1     no southeast  8083.91980
#   64   male 33.880         0    yes southeast 46889.26120
#   61   male 35.860         0    yes southeast 46599.10840
#   40   male 32.775         1    yes northeast 39125.33225
#   33 female 33.500         0    yes southwest 37079.37200
#   24   male 28.500         0    yes northeast 35147.52848
#   44 female 38.060         0    yes southeast 48885.13561
#   29   male 34.400         0    yes southwest 36197.69900
#   42   male 26.070         1    yes southeast 38245.59327
#   57   male 42.130         1    yes southeast 48675.51770
#   54 female 47.410         0    yes southeast 63770.42801
#   43 female 46.200         0    yes southeast 45863.20500
#   35 female 34.105         3    yes northwest 39983.42595
#   48   male 40.565         2    yes northwest 45702.02235
#   31 female 38.095         1    yes northeast 58571.07448
#   34 female 30.210         1    yes northwest 43943.87610
#   30   male 37.800         2    yes southwest 39241.44200
#   47 female 36.630         1    yes southeast 42969.85270
#   37   male 34.100         4    yes southwest 40182.24600
#   18   male 33.535         0    yes northeast 34617.84065
#   44 female 38.950         0    yes northwest 42983.45850
#   43   male 38.060         2    yes southeast 42560.43040
#   40 female 32.775         2    yes northwest 40003.33225
#   62   male 32.015         0    yes northeast 45710.20785
#   44 female 43.890         2    yes southeast 46200.98510
#   60   male 31.350         3    yes northwest 46130.52650
#   39   male 35.300         2    yes southwest 40103.89000
#   27   male 31.130         1    yes southeast 34806.46770
#   41   male 35.750         1    yes southeast 40273.64550
#   51 female 38.060         0    yes southeast 44400.40640
#   30 female 39.050         3    yes southeast 40932.42950
#   37 female 38.390         0    yes southeast 40419.01910
#   23   male 31.730         3    yes northeast 36189.10170
#   29   male 35.500         2    yes southwest 44585.45587
#   53   male 34.105         0    yes northeast 43254.41795
#   18   male 38.170         0    yes southeast 36307.79830
#   18 female 42.240         0    yes southeast 38792.68560
#   33 female 35.530         0    yes northwest 55135.40209
#   56   male 31.790         2    yes southeast 43813.86610
#   41   male 30.780         3    yes northeast 39597.40720
#   23 female 32.780         2    yes southeast 36021.01120
#   60 female 32.450         0    yes southeast 45008.95550
#   23   male 50.380         1     no southeast  2438.05520
#   37 female 30.780         0    yes northeast 37270.15120
#   46 female 35.530         0    yes northeast 42111.66470
#   48 female 33.110         0    yes southeast 40974.16490
#   37 female 47.600         2    yes southwest 46113.51100
#   51 female 37.050         3    yes northeast 46255.11250
#   47   male 38.940         2    yes southeast 44202.65360
#   60   male 40.920         0    yes southeast 48673.55880
#   45   male 22.895         0    yes northeast 35069.37452
#   37   male 34.200         1    yes northeast 39047.28500
#   51   male 42.900         2    yes southeast 47462.89400
#   44   male 30.200         2    yes southwest 38998.54600
#   54   male 30.800         1    yes southeast 41999.52000
#   43   male 34.960         1    yes northeast 41034.22140
#   61 female 33.330         4     no southeast 36580.28216
#   22 female 31.020         3    yes southeast 35595.58980
#   47   male 36.080         1    yes southeast 42211.13820
#   55 female 35.200         0    yes southeast 44423.80300
#   22   male 37.070         2    yes southeast 37484.44930
#   45 female 30.495         1    yes northwest 39725.51805
#   22   male 52.580         1    yes southeast 44501.39820
#   49   male 30.900         0    yes southwest 39727.61400
#   59   male 41.140         1    yes southeast 48970.24760
#   37   male 37.070         1    yes southeast 39871.70430
#   28   male 31.680         0    yes southeast 34672.14720
#   52   male 47.740         1     no southeast  9748.91060
#   47   male 36.190         0    yes southeast 41676.08110
#   51 female 34.960         2    yes northeast 44641.19740
#   38   male 38.390         3    yes southeast 41949.24410
#   25   male 33.330         2    yes southeast 36124.57370
#   33   male 35.750         1    yes southeast 38282.74950
#   53 female 36.860         3    yes northwest 46661.44240
#   23 female 42.750         1    yes northeast 40904.19950
#   19 female 32.490         0    yes northwest 36898.73308
#   60   male 32.800         0    yes southwest 52590.82939
#   43 female 32.560         3    yes southeast 40941.28540
#   19   male 44.880         0    yes southeast 39722.74620
#   20   male 35.625         3    yes northwest 37465.34375
#   59 female 34.800         2     no southwest 36910.60803
#   36   male 33.400         2    yes southwest 38415.47400
#   46 female 34.600         1    yes southwest 41661.60200
#   52   male 34.485         3    yes northwest 60021.39897
#   52   male 41.800         2    yes southeast 47269.85400
#   64   male 36.960         2    yes southeast 49577.66240
#   32   male 33.630         1    yes northeast 37607.52770
#   61   male 36.300         1    yes southwest 47403.88000
#   20   male 39.400         2    yes southwest 38344.56600
#   19   male 34.900         0    yes southwest 34828.65400
#   45   male 30.360         0    yes southeast 62592.87309
#   62   male 30.875         3    yes northwest 46718.16325
#   43   male 27.800         0    yes southwest 37829.72420
#   19 female 34.700         2    yes southwest 36397.57600
#   18   male 53.130         0     no southeast  1163.46270
#   42 female 40.370         2    yes southeast 43896.37630
# con you plot the correlatio between bmi and charges
#
# 🤖 Generated Code:
#
#
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# fig, ax = plt.subplots()
# sns.regplot(data=df, x='bmi', y='charges', ax=ax, scatter_kws={'alpha':0.6})
# ax.set_title('Correlation between BMI and Charges')
# result = ax
#
#
# 📈 Final Result:
#
# Axes(0.125,0.11;0.775x0.77)
# exit
#
# 🤖 Generated Code:
#
#
# result = None
#
#
# 📈 Final Result:
#
# None
# exit
#
# 🤖 Generated Code:
#
#
# result = None
#
#
# 📈 Final Result:
#
# None
# exit
#
# 🤖 Generated Code:
#
#
# result = None
#
#
# 📈 Final Result:
#
# None
#
#
# 🤖 Generated Code:
#
#
# result = None
#
#
# 📈 Final Result:
#
# None

# %%
# Out:
# None
